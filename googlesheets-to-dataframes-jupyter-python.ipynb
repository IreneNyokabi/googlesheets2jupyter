# %% [markdown]
# # Install Packages

# %%
import pandas as pd 
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import sqlalchemy

# %%
#https://towardsdatascience.com/from-google-sheet-to-your-jupyter-notebook-ccdbf28fbf1b

# %% [markdown]
# # Create a service object

# %%
#The scope is always look like this so we did not need to change anything
scope = [
   'https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
#Name of our Service Account Key
#downloaded from (https://console.cloud.google.com/) and saved in the same folder as your project
google_key_file = 'service_account_GS.json'
credentials = ServiceAccountCredentials.from_json_keyfile_name(google_key_file, scope)
gc = gspread.authorize(credentials)

# %% [markdown]
# # Read from sheetID

# %%
#Opening the worksheet by using Worksheet ID
#share the google sheet document with the email from your service_account_GS.json above. If you miss this, you will not be able to extract data from the sheet
workbook = gc.open_by_key('{spreadsheet-key}')
#Selecting which sheet to pulling the data
sheet = workbook.worksheet('{tab-data-is-in-googlesheet}')
#Pulling the data and transform it to the data frame
values = sheet.get_all_values()
response = pd.DataFrame(values[1:], columns = values[0])
response

## response is now the name of your dataframe and you can use it to transform your data
# Out:
#          Source                                       Landing Page  \
# 0      (direct)                                          (not set)
# 1      (direct)                                                  /
# 2      (direct)                                                  /
# 3      (direct)                                                  /
# 4      (direct)                                                  /
# ...         ...                                                ...
# 39843   zoso.ro  /stiri/surse-document-armata-proiect-lege-situ...
# 39844   zoso.ro  /stiri/tanara-anchetata-rusia-protest-agresata...
# 39845   zoso.ro  /stiri/tudorel-toader-o-apara-pe-elena-udrea-i...
# 39846   zoso.ro  /stiri/val-de-indignare-dupa-ce-un-politician-...
# 39847   zoso.ro  /stiri/video-cum-arata-acum-mall-urile-din-rus...
#
#              Date                                         Page Title Entrances
# 0      2022-03-07                                          (not set)       333
# 1      2022-03-07                                             Jocuri         3
# 2      2022-03-07  Ziar Online - Bästa rumänska nyhetssajten | Fr...         2
# 3      2022-03-07  Ziar Online - El mejor sitio de noticias ruman...         2
# 4      2022-03-07  Ziar Online - Románia legjobb híroldala | Szab...         1
# ...           ...                                                ...       ...
# 39843  2022-03-07  Bărbații Români între 18 și 60 De Ani, în Reze...         1
# 39844  2022-03-07  AUDIO. Protestară Din Moscova, Bătută și Umili...         1
# 39845  2022-03-07  Tudorel Toader O Apără Pe Elena Udrea în Proce...         1
# 39846  2022-03-07  Val De Indignare După Ce Un Politician A Spus ...        77
# 39847  2022-03-07  VIDEO. Cum Arată Acum Mall-urile Din Rusia La ...         1
#
# [39848 rows x 5 columns]
